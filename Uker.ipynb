# %%
import pandas as pd
#import json

uker = pd.DataFrame(range(52), index=pd.date_range("2021", freq="W-MON", periods=52))
uker['Weekday'] = 'Monday'
uker['Hourly wage - regular [NOK]'] = 160.10
uker['Hourly wage - regular [USD]'] = round(160.10 / 8.48, 2)
uker['Hourly wage - bachelor [NOK]'] = 164.10
uker['Hourly wage - bachelor [USD]'] = round(164.10 / 8.48, 2)
uker['Hourly wage - master [NOK]'] = 168.41
uker['Hourly wage - master [USD]'] = round(168.41 / 8.48, 2)
uker

uker.to_json (r'C:\Users\alexm\Enry\uker.json', orient='index')

uker
# Out:
#              0 Weekday  Hourly wage - regular [NOK]  \
# 2021-01-04   0  Monday                        160.1
# 2021-01-11   1  Monday                        160.1
# 2021-01-18   2  Monday                        160.1
# 2021-01-25   3  Monday                        160.1
# 2021-02-01   4  Monday                        160.1
# 2021-02-08   5  Monday                        160.1
# 2021-02-15   6  Monday                        160.1
# 2021-02-22   7  Monday                        160.1
# 2021-03-01   8  Monday                        160.1
# 2021-03-08   9  Monday                        160.1
# 2021-03-15  10  Monday                        160.1
# 2021-03-22  11  Monday                        160.1
# 2021-03-29  12  Monday                        160.1
# 2021-04-05  13  Monday                        160.1
# 2021-04-12  14  Monday                        160.1
# 2021-04-19  15  Monday                        160.1
# 2021-04-26  16  Monday                        160.1
# ...
